# %% [markdown]
# # Imports

# %%
import tensorflow
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Build Model

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(2,activation='relu',input_dim=2))
model.add(keras.layers.Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# # Training Data

# %%
training_data = [[0,0],[0,1],[1,0],[1,1]]
training_labels = [[0],[1],[1],[1]]

X = np.asarray(training_data)
Y = np.asarray(training_labels)

# %% [markdown]
# # Train Model

# %%
history = model.fit(X,Y,batch_size=1,epochs=1000)
model.save('OR_weights')
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 3ms/step - loss: 0.5908 - accuracy: 0.7500
# Epoch 2/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5891 - accuracy: 0.7500
# Epoch 3/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5880 - accuracy: 0.7500
# Epoch 4/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5858 - accuracy: 0.7500
# Epoch 5/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5844 - accuracy: 0.7500
# Epoch 6/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5835 - accuracy: 0.7500
# Epoch 7/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5816 - accuracy: 0.7500
# Epoch 8/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5802 - accuracy: 0.7500
# Epoch 9/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5787 - accuracy: 0.7500
# Epoch 10/1000
# ...

# %% [markdown]
# # Test Model

# %%
print(model.predict(np.asarray([[0,0]])))
print(model.predict(np.asarray([[1,0]])))
print(model.predict(np.asarray([[0,1]])))
print(model.predict(np.asarray([[1,1]])))
# Out:
# [[0.31578866]]
# [[0.97879]]
# [[0.9895677]]
# [[0.9998946]]

# %% [markdown]
# # Visualize

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in model.layers:
    print('Layer Name: ' + layer.name)
    print('Layer Type: ' + layer.__class__.__name__)
    print('Layer input shape: {}'.format(layer.input_shape))
    print('Layer output shape: {}'.format(layer.output_shape))
    print('Layer parameter count: {}'.format(layer.count_params()))
    print('Layer weights: \n{}'.format(layer.weights))
    print()
# Out:
# Layer Name: dense
# Layer Type: Dense
# Layer input shape: (None, 2)
# Layer output shape: (None, 2)
# Layer parameter count: 6
# Layer weights:
# [<tf.Variable 'dense/kernel:0' shape=(2, 2) dtype=float32, numpy=
# array([[-0.4276824 ,  1.4519336 ],
#        [-0.60087633,  1.6791062 ]], dtype=float32)>, <tf.Variable 'dense/bias:0' shape=(2,) dtype=float32, numpy=array([0.        , 0.00014727], dtype=float32)>]
#
# Layer Name: dense_1
# Layer Type: Dense
# Layer input shape: (None, 2)
# Layer output shape: (None, 1)
# Layer parameter count: 3
# Layer weights:
# [<tf.Variable 'dense_1/kernel:0' shape=(2, 1) dtype=float32, numpy=
# array([[-0.6054894],
#        [ 3.171659 ]], dtype=float32)>, <tf.Variable 'dense_1/bias:0' shape=(1,) dtype=float32, numpy=array([-0.77366066], dtype=float32)>]

# %%
from keras_visualizer import visualizer

visualizer(model, format='png',view=True)

# %% [markdown]
# # Visualize Loss

# %%
loss_values = history.history['loss']

epochs = range(1, len(loss_values)+1)

plt.plot(epochs, loss_values, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# # Visualize Accuracy

# %%
accuracy = history.history['accuracy']

plt.plot(epochs, accuracy, label='Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
